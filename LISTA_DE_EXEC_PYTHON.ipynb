# %% [markdown]
# <a href="https://colab.research.google.com/github/evelinpereiracosta30/PYTHON/blob/main/LISTA_DE_EXEC_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n1 = int (input('1º número:'))
n2 = int (input('2º número'))
print (n1 + n2)

# %%
msg = 'olá mundo'
print (olá mundo)

# %%
m = int(input('metros'))
print ('milimítros:', m * 1000)

# %%
d = int(input('dias: '))
h = int(input('horas: '))
m = int(input('minutos: '))
s_input = input('segundos: ')
s = int(s_input) if s_input.strip() else 0
total = d * 24 * 60* 60 + h * 60 * 60 + m * 60 + s
print (total)

# %%
s = float(input('salário: '))
p = float(input('porcentagem de aumento: '))
aumento = s * p / 100
novo = s + aumento
print('aumento: R$ %.2f '%aumento)
print('novo salário: $ %.2f' %novo)

# %%
m = float(input('preço da mercadoria: '))
p = float(input('porcentagem de desconto: '))
desconto = m * p / 100
novo = m - desconto
print('desconto: R$ %.2f' %desconto)
print('preço a pagar: R$ %.2f' %novo)

# %%
d =  float(input('distância em km: '))
v = float(input('velocidade média em km/h'))
t = d / v
minutos = (roud(t % 1, 2)) * 60
print('tempo aproximado de %2.0f horas e %2.f minutos' %(t,minutos))

# %%
vetor = []
for i in range(20):
  if i % 2 == 0:
    vetor.append(1)
  else:
      vetor.append(0)
      print("vetor: ", vetor)
